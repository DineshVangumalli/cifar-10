# %%
import tensorflow
tensorflow.__version__
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# '1.4.0'

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.1.0'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import SGD
from keras.optimizers import RMSprop
from keras.utils import np_utils

np.random.seed(100)
# %matplotlib inline

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
def draw_img(i):
    im = X_train[i]
    c = y_train[i]
    plt.imshow(im)
    plt.axis('on')

def draw_sample(X, y, n, rows=4, cols=4, imfile=None, fontsize=12):
    for i in range(0, rows*cols):
        plt.subplot(rows, cols, i+1)
        im = X[n+i].reshape(32,32,3)
        plt.imshow(im, cmap='gnuplot2')
        plt.axis('off')
        plt.subplots_adjust(wspace=0.8, hspace=0.01)
        
    if imfile:
        plt.savefig(imfile)

# %%
draw_sample(X_train, y_train, 0, 5, 5)

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
y_train = y_train.reshape(y_train.shape[0])  #y_train comes as a 2D nx1 matrix
y_test = y_test.reshape(y_test.shape[0])

# %%
y_train.shape
# Out:
# (50000,)

# %%
label_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Size of the batch
batch_size = 32
# Number of classes of images
nb_classes = 10
# Number of epochs for learning
num_epochs = 100
# Size of the images
img_rows, img_cols = 32, 32
# Number of channels in the image: RGB
img_channels = 3

# %%
# Normalize the data
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# %%
# Convert the labels to categories
y_train = np_utils.to_categorical(y_train, 10)
y_test = np_utils.to_categorical(y_test, 10)

# %%
y_train.shape
# Out:
# (50000, 10)

# %%
# Create a model
model = Sequential()

# The first convolutional layer
model.add(Conv2D(32, (3, 3), padding='same', input_shape=(32, 32, 3), activation='relu'))
# The second convolutional layer
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
# The first pooling Layer
model.add(MaxPooling2D(pool_size=(2, 2)))
# Dropout regularization layer
model.add(Dropout(0.25))

# The third convolutional layer
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
# The fourth convolutional layer
model.add(Conv2D(64, (3, 3), activation='relu'))
# The second pooling layer
model.add(MaxPooling2D(pool_size=(2, 2)))
# Dropout regularization layer
model.add(Dropout(0.25))

# Flatten the dataset
model.add(Flatten())
# A fully-connected layer for classification
model.add(Dense(512, activation='relu'))
# Dropout regularization layer
model.add(Dropout(0.5))

# Output/Softmax layer
model.add(Dense(nb_classes, activation='softmax'))

# %%
sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
# %%time
history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=num_epochs,
          validation_split=0.1,
          shuffle=True,
          verbose=2)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 21s - loss: 2.0591 - acc: 0.2377 - val_loss: 1.7816 - val_acc: 0.3744
# Epoch 2/100
#  - 20s - loss: 1.7066 - acc: 0.3778 - val_loss: 1.5423 - val_acc: 0.4460
# Epoch 3/100
#  - 20s - loss: 1.5390 - acc: 0.4417 - val_loss: 1.4081 - val_acc: 0.4968
# Epoch 4/100
#  - 20s - loss: 1.4200 - acc: 0.4855 - val_loss: 1.3021 - val_acc: 0.5338
# Epoch 5/100
#  - 20s - loss: 1.3331 - acc: 0.5195 - val_loss: 1.2271 - val_acc: 0.5660
# Epoch 6/100
#  - 20s - loss: 1.2686 - acc: 0.5461 - val_loss: 1.1641 - val_acc: 0.5930
# Epoch 7/100
#  - 20s - loss: 1.1988 - acc: 0.5725 - val_loss: 1.0987 - val_acc: 0.6128
# Epoch 8/100
#  - 20s - loss: 1.1481 - acc: 0.5904 - val_loss: 1.0617 - val_acc: 0.6378
# Epoch 9/100
#  - 19s - loss: 1.0959 - acc: 0.6101 - val_loss: 0.9863 - val_acc: 0.6532
# Epoch 10/100
#  - 19s - loss: 1.0499 - acc: 0.6278 - val_loss: 0.9505 - val_acc: 0.6662
# Epoch 11/100
#  - 19s - loss: 1.0021 - acc: 0.6474 - val_loss: 0.9012 - val_acc: 0.6912
# Epoch 12/100
#  - 19s - loss: 0.9646 - acc: 0.6608 - val_loss: 0.8790 - val_acc: 0.7018
# Epoch 13/100
#  - 19s - loss: 0.9244 - acc: 0.6744 - val_loss: 0.8281 - val_acc: 0.7182
# Epoch 14/100
#  - 20s - loss: 0.8926 - acc: 0.6858 - val_loss: 0.8223 - val_acc: 0.7126
# Epoch 15/100
#  - 19s - loss: 0.8651 - acc: 0.6938 - val_loss: 0.7682 - val_acc: 0.7336
# Epoch 16/100
#  - 19s - loss: 0.8316 - acc: 0.7084 - val_loss: 0.7477 - val_acc: 0.7454
# Epoch 17/100
#  - 19s - loss: 0.8087 - acc: 0.7152 - val_loss: 0.7452 - val_acc: 0.7430
# Epoch 18/100
#  - 20s - loss: 0.7827 - acc: 0.7237 - val_loss: 0.7280 - val_acc: 0.7482
# Epoch 19/100
#  - 19s - loss: 0.7531 - acc: 0.7334 - val_loss: 0.7507 - val_acc: 0.7448
# Epoch 20/100
#  - 19s - loss: 0.7364 - acc: 0.7403 - val_loss: 0.7005 - val_acc: 0.7564
# Epoch 21/100
#  - 20s - loss: 0.7190 - acc: 0.7478 - val_loss: 0.6848 - val_acc: 0.7676
# Epoch 22/100
#  - 20s - loss: 0.7039 - acc: 0.7514 - val_loss: 0.6900 - val_acc: 0.7664
# Epoch 23/100
#  - 20s - loss: 0.6824 - acc: 0.7593 - val_loss: 0.6557 - val_acc: 0.7738
# Epoch 24/100
#  - 20s - loss: 0.6633 - acc: 0.7641 - val_loss: 0.6559 - val_acc: 0.7728
# Epoch 25/100
#  - 20s - loss: 0.6502 - acc: 0.7717 - val_loss: 0.6391 - val_acc: 0.7750
# Epoch 26/100
#  - 20s - loss: 0.6341 - acc: 0.7772 - val_loss: 0.6584 - val_acc: 0.7750
# Epoch 27/100
#  - 20s - loss: 0.6191 - acc: 0.7809 - val_loss: 0.6264 - val_acc: 0.7846
# Epoch 28/100
#  - 19s - loss: 0.5996 - acc: 0.7890 - val_loss: 0.6205 - val_acc: 0.7868
# Epoch 29/100
#  - 20s - loss: 0.5866 - acc: 0.7923 - val_loss: 0.6226 - val_acc: 0.7838
# Epoch 30/100
#  - 20s - loss: 0.5710 - acc: 0.7980 - val_loss: 0.6286 - val_acc: 0.7872
# Epoch 31/100
#  - 20s - loss: 0.5596 - acc: 0.8026 - val_loss: 0.6111 - val_acc: 0.7920
# Epoch 32/100
#  - 20s - loss: 0.5460 - acc: 0.8057 - val_loss: 0.6012 - val_acc: 0.7936
# Epoch 33/100
#  - 19s - loss: 0.5330 - acc: 0.8109 - val_loss: 0.6081 - val_acc: 0.7908
# Epoch 34/100
#  - 20s - loss: 0.5178 - acc: 0.8167 - val_loss: 0.6057 - val_acc: 0.7978
# Epoch 35/100
#  - 20s - loss: 0.5008 - acc: 0.8217 - val_loss: 0.5962 - val_acc: 0.8016
# Epoch 36/100
#  - 20s - loss: 0.4917 - acc: 0.8243 - val_loss: 0.5934 - val_acc: 0.8010
# Epoch 37/100
#  - 20s - loss: 0.4835 - acc: 0.8279 - val_loss: 0.5956 - val_acc: 0.8010
# Epoch 38/100
#  - 20s - loss: 0.4714 - acc: 0.8314 - val_loss: 0.6083 - val_acc: 0.7960
# Epoch 39/100
#  - 20s - loss: 0.4654 - acc: 0.8317 - val_loss: 0.5945 - val_acc: 0.8036
# Epoch 40/100
#  - 20s - loss: 0.4456 - acc: 0.8412 - val_loss: 0.5888 - val_acc: 0.8054
# Epoch 41/100
#  - 19s - loss: 0.4406 - acc: 0.8418 - val_loss: 0.5953 - val_acc: 0.8026
# Epoch 42/100
#  - 19s - loss: 0.4283 - acc: 0.8455 - val_loss: 0.5928 - val_acc: 0.8008
# Epoch 43/100
#  - 20s - loss: 0.4211 - acc: 0.8503 - val_loss: 0.6113 - val_acc: 0.7940
# Epoch 44/100
#  - 20s - loss: 0.4085 - acc: 0.8539 - val_loss: 0.5886 - val_acc: 0.8030
# Epoch 45/100
#  - 19s - loss: 0.4001 - acc: 0.8582 - val_loss: 0.5965 - val_acc: 0.8060
# Epoch 46/100
#  - 19s - loss: 0.3959 - acc: 0.8596 - val_loss: 0.5825 - val_acc: 0.8042
# Epoch 47/100
#  - 20s - loss: 0.3793 - acc: 0.8633 - val_loss: 0.5987 - val_acc: 0.8048
# Epoch 48/100
#  - 20s - loss: 0.3778 - acc: 0.8636 - val_loss: 0.5787 - val_acc: 0.8098
# Epoch 49/100
#  - 19s - loss: 0.3611 - acc: 0.8704 - val_loss: 0.6064 - val_acc: 0.8092
# Epoch 50/100
#  - 20s - loss: 0.3607 - acc: 0.8700 - val_loss: 0.5953 - val_acc: 0.8082
# Epoch 51/100
#  - 20s - loss: 0.3476 - acc: 0.8761 - val_loss: 0.6006 - val_acc: 0.8074
# Epoch 52/100
#  - 20s - loss: 0.3436 - acc: 0.8766 - val_loss: 0.6026 - val_acc: 0.8042
# Epoch 53/100
#  - 20s - loss: 0.3280 - acc: 0.8814 - val_loss: 0.6054 - val_acc: 0.8088
# Epoch 54/100
#  - 20s - loss: 0.3255 - acc: 0.8824 - val_loss: 0.6067 - val_acc: 0.8030
# Epoch 55/100
#  - 20s - loss: 0.3214 - acc: 0.8826 - val_loss: 0.5973 - val_acc: 0.8088
# Epoch 56/100
#  - 20s - loss: 0.3105 - acc: 0.8878 - val_loss: 0.5987 - val_acc: 0.8128
# Epoch 57/100
#  - 20s - loss: 0.3068 - acc: 0.8913 - val_loss: 0.6016 - val_acc: 0.8104
# Epoch 58/100
#  - 19s - loss: 0.2978 - acc: 0.8928 - val_loss: 0.6106 - val_acc: 0.8122
# Epoch 59/100
#  - 20s - loss: 0.2890 - acc: 0.8966 - val_loss: 0.6098 - val_acc: 0.8080
# Epoch 60/100
#  - 21s - loss: 0.2867 - acc: 0.8954 - val_loss: 0.6077 - val_acc: 0.8084
# Epoch 61/100
#  - 21s - loss: 0.2846 - acc: 0.8962 - val_loss: 0.6005 - val_acc: 0.8122
# Epoch 62/100
#  - 21s - loss: 0.2776 - acc: 0.9009 - val_loss: 0.6123 - val_acc: 0.8098
# Epoch 63/100
#  - 21s - loss: 0.2694 - acc: 0.9022 - val_loss: 0.6114 - val_acc: 0.8092
# Epoch 64/100
#  - 21s - loss: 0.2594 - acc: 0.9076 - val_loss: 0.6083 - val_acc: 0.8114
# Epoch 65/100
#  - 21s - loss: 0.2602 - acc: 0.9059 - val_loss: 0.6238 - val_acc: 0.8122
# Epoch 66/100
#  - 21s - loss: 0.2560 - acc: 0.9085 - val_loss: 0.6048 - val_acc: 0.8118
# Epoch 67/100
#  - 21s - loss: 0.2521 - acc: 0.9098 - val_loss: 0.6130 - val_acc: 0.8128
# Epoch 68/100
#  - 21s - loss: 0.2486 - acc: 0.9103 - val_loss: 0.6378 - val_acc: 0.8078
# Epoch 69/100
#  - 21s - loss: 0.2462 - acc: 0.9119 - val_loss: 0.6199 - val_acc: 0.8112
# Epoch 70/100
#  - 21s - loss: 0.2352 - acc: 0.9152 - val_loss: 0.6304 - val_acc: 0.8110
# Epoch 71/100
#  - 21s - loss: 0.2338 - acc: 0.9159 - val_loss: 0.6289 - val_acc: 0.8152
# Epoch 72/100
#  - 21s - loss: 0.2273 - acc: 0.9196 - val_loss: 0.6289 - val_acc: 0.8178
# Epoch 73/100
#  - 21s - loss: 0.2238 - acc: 0.9190 - val_loss: 0.6731 - val_acc: 0.8076
# Epoch 74/100
#  - 21s - loss: 0.2236 - acc: 0.9206 - val_loss: 0.6363 - val_acc: 0.8114
# Epoch 75/100
#  - 21s - loss: 0.2190 - acc: 0.9212 - val_loss: 0.6341 - val_acc: 0.8170
# Epoch 76/100
#  - 21s - loss: 0.2144 - acc: 0.9224 - val_loss: 0.6294 - val_acc: 0.8208
# Epoch 77/100
#  - 21s - loss: 0.2065 - acc: 0.9269 - val_loss: 0.6546 - val_acc: 0.8114
# Epoch 78/100
#  - 21s - loss: 0.2067 - acc: 0.9244 - val_loss: 0.6454 - val_acc: 0.8160
# Epoch 79/100
#  - 21s - loss: 0.2060 - acc: 0.9268 - val_loss: 0.6287 - val_acc: 0.8200
# Epoch 80/100
#  - 20s - loss: 0.2015 - acc: 0.9275 - val_loss: 0.6371 - val_acc: 0.8162
# Epoch 81/100
#  - 20s - loss: 0.1997 - acc: 0.9290 - val_loss: 0.6471 - val_acc: 0.8120
# Epoch 82/100
#  - 20s - loss: 0.1974 - acc: 0.9302 - val_loss: 0.6400 - val_acc: 0.8184
# Epoch 83/100
#  - 21s - loss: 0.1939 - acc: 0.9317 - val_loss: 0.6522 - val_acc: 0.8160
# Epoch 84/100
#  - 21s - loss: 0.1891 - acc: 0.9316 - val_loss: 0.6752 - val_acc: 0.8098
# Epoch 85/100
#  - 20s - loss: 0.1874 - acc: 0.9325 - val_loss: 0.6431 - val_acc: 0.8180
# Epoch 86/100
#  - 20s - loss: 0.1862 - acc: 0.9334 - val_loss: 0.6498 - val_acc: 0.8140
# Epoch 87/100
#  - 20s - loss: 0.1791 - acc: 0.9356 - val_loss: 0.6499 - val_acc: 0.8144
# Epoch 88/100
#  - 20s - loss: 0.1823 - acc: 0.9354 - val_loss: 0.6570 - val_acc: 0.8136
# Epoch 89/100
#  - 21s - loss: 0.1739 - acc: 0.9376 - val_loss: 0.6801 - val_acc: 0.8122
# Epoch 90/100
#  - 21s - loss: 0.1707 - acc: 0.9385 - val_loss: 0.6767 - val_acc: 0.8150
# Epoch 91/100
#  - 21s - loss: 0.1734 - acc: 0.9385 - val_loss: 0.6785 - val_acc: 0.8110
# Epoch 92/100
#  - 20s - loss: 0.1736 - acc: 0.9383 - val_loss: 0.6750 - val_acc: 0.8144
# Epoch 93/100
#  - 20s - loss: 0.1666 - acc: 0.9408 - val_loss: 0.7138 - val_acc: 0.8142
# Epoch 94/100
#  - 20s - loss: 0.1609 - acc: 0.9415 - val_loss: 0.6759 - val_acc: 0.8150
# Epoch 95/100
#  - 20s - loss: 0.1670 - acc: 0.9398 - val_loss: 0.6677 - val_acc: 0.8160
# Epoch 96/100
#  - 20s - loss: 0.1594 - acc: 0.9429 - val_loss: 0.6656 - val_acc: 0.8202
# Epoch 97/100
#  - 20s - loss: 0.1604 - acc: 0.9433 - val_loss: 0.6740 - val_acc: 0.8212
# Epoch 98/100
#  - 20s - loss: 0.1583 - acc: 0.9434 - val_loss: 0.6671 - val_acc: 0.8142
# Epoch 99/100
#  - 20s - loss: 0.1543 - acc: 0.9455 - val_loss: 0.6679 - val_acc: 0.8166
# Epoch 100/100
#  - 20s - loss: 0.1513 - acc: 0.9457 - val_loss: 0.6828 - val_acc: 0.8196
# CPU times: user 35min 25s, sys: 3min 15s, total: 38min 40s
# Wall time: 33min 19s

# %%
model_json = model.to_json()
open('cifar10_architecture1_sgd100_4L.json', 'w').write(model_json)

# Save the weights learned by the deep neural network on the training data
model.save_weights('cifar10_weights_sgd100_4L.h5')

# %%
# %%time
scores = model.evaluate(X_test, y_test, verbose=2)
print("The accuracy of the test data: %.2f%%" % (scores[1]*100))
# Out:
# The accuracy of the test data: 81.02%
# CPU times: user 1.25 s, sys: 88 ms, total: 1.34 s
# Wall time: 1.54 s

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,676,842
# Trainable params: 1,676,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = model.predict(X_test, verbose=2)
y_pred = np.argmax(Y_pred, axis=1)
 
conf_mx = confusion_matrix(np.argmax(y_test, axis=1), y_pred)
conf_mx
# Out:
# array([[848,   8,  29,  11,  16,   1,   7,   9,  40,  31],
#        [  9, 898,   1,   2,   5,   4,   5,   1,  15,  60],
#        [ 57,   4, 661,  42,  92,  46,  51,  22,  15,  10],
#        [ 18,   8,  42, 598,  65, 137,  68,  32,  15,  17],
#        [ 13,   3,  34,  36, 824,  15,  27,  37,   7,   4],
#        [ 11,   1,  30, 129,  38, 722,  15,  44,   6,   4],
#        [  4,   5,  27,  32,  24,   5, 892,   3,   5,   3],
#        [  8,   1,  25,  26,  35,  29,   3, 864,   1,   8],
#        [ 45,  17,   2,   3,   4,   4,   4,   2, 901,  18],
#        [ 15,  46,   1,   9,   3,   2,   4,   7,  19, 894]])

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

from keras.preprocessing.image import load_img, img_to_array
from keras.models import model_from_json

# %matplotlib inline

# Scratch Model
weights_path = 'cifar10_weights_sgd100_4L.h5'
model_path = 'cifar10_architecture1_sgd100_4L.json'

label_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import scipy

def preprocess_image(image_path, preprocess_input, resize_shape):
    img = load_img(image_path)
    img = img_to_array(img)
    img = scipy.misc.imresize(img, size=resize_shape)
    img = preprocess_input(img)
    return img

# %%
with open(model_path, 'r') as model_json:
    loaded_model = model_from_json(model_json.read())

loaded_model.load_weights(weights_path)
print("Scratch Model Loaded")
# Out:
# Scratch Model Loaded

# %%
img = preprocess_image('images/deer.jpg', lambda x: x/255, (32, 32, 3))
pred = label_names[np.argmax(loaded_model.predict(np.expand_dims(img, axis=0)))]

plt.axis('off')
plt.imshow(img)
plt.title(pred)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# Text(0.5,1,'cat')

# %%
img = preprocess_image('images/horse.jpg', lambda x: x/255, (32, 32, 3))
pred = label_names[np.argmax(loaded_model.predict(np.expand_dims(img, axis=0)))]

plt.axis('off')
plt.imshow(img)
plt.title(pred)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# Text(0.5,1,'horse')

# %%
img = preprocess_image('images/dog.jpg', lambda x: x/255, (32, 32, 3))
pred = label_names[np.argmax(loaded_model.predict(np.expand_dims(img, axis=0)))]

plt.axis('off')
plt.imshow(img)
plt.title(pred)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# Text(0.5,1,'dog')

# %%
img = preprocess_image('images/dinesh.jpg', lambda x: x/255, (32, 32, 3))
pred = label_names[np.argmax(loaded_model.predict(np.expand_dims(img, axis=0)))]

plt.axis('off')
plt.imshow(img)
plt.title(pred)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# Text(0.5,1,'deer')

# %% [markdown]
# ## References
# https://github.com/JacobPolloreno/cifar10_keras<br>
# Deep Learning with Keras by Antonio Gulli and Sujit Pal<br>
# http://www.samyzaf.com/ML/cifar10/cifar10.html<br>
# https://github.com/charlesgreen/keras_cifar10_cnn/blob/master/keras_cifar10_cnn/cifar10_cnn.py<br>
# https://machinelearningmastery.com/image-augmentation-deep-learning-keras/<br>
# https://www.kernix.com/blog/a-toy-convolutional-neural-network-for-image-classification-with-keras_p14
